# %%
import pandas as pd

def read_csv_to_dataframe(file_path):
    df = pd.read_csv(file_path)
    return df

# Usage example
file_path = 'E:\\github\\nexis_uni_extractor\\test\\data\\1.csv'
data_frame = read_csv_to_dataframe(file_path)
display(data_frame[50:60])
# Out:
#                                                 title  \
# 50  India's WPI inflation at (-) 0.92% in April, l...
# 51  Bank of England admits it made errors in infla...
# 52               Inflation: exploring its real nature
# 53           Russia's inflation down to 2.3% in April
# 54           'Public pay deal should match inflation'
# 55  Polish core inflation dips 0.1pp to 12.2% y/y ...
# 56           Inflation, interest rate and imperialism
# 57          Managing family finances during inflation
# 58         Labor-intensive services support inflation
# 59  Inflation reached an annual rate of 6%, the be...
#
#                            publisher publish_date edition  \
# 50         Millennium Post Newspaper   2023/05/17     NaN
# 51  The Independent (United Kingdom)   2023/05/23     NaN
# 52   CE Noticias Financieras English   2023/05/09     NaN
# 53        Intellinews - Russia Today   2023/05/16     NaN
# 54                    Irish Examiner   2023/05/13     NaN
# ...
